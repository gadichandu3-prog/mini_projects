# %% [markdown]
# <a href="https://colab.research.google.com/github/gadichandu3-prog/mini_projects/blob/main/Mini_Projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'city': ['Hyd', 'kkd', 'vzg', 'Hyd', 'vzg', 'kkd', 'bangalore'],
    'humidity': [34.0, 45.0, 56.0, 23.0, 34.0, None, 78.0],
    'temp': [56.0, 67.0, None, 32.0, 89.0, 67.0, 67.0]
}

df = pd.DataFrame(data)
print(df)
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0   NaN
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd       NaN  67.0
# 6  bangalore      78.0  67.0

# %%
df.isnull()
# Out:
#     city  humidity   temp
# 0  False     False  False
# 1  False     False  False
# 2  False     False   True
# 3  False     False  False
# 4  False     False  False
# 5  False      True  False
# 6  False     False  False

# %%
df.head()
# Out:
#   city  humidity  temp
# 0  Hyd      34.0  56.0
# 1  kkd      45.0  67.0
# 2  vzg      56.0   NaN
# 3  Hyd      23.0  32.0
# 4  vzg      34.0  89.0

# %%
df.tail()
# Out:
#         city  humidity  temp
# 2        vzg      56.0   NaN
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd       NaN  67.0
# 6  bangalore      78.0  67.0

# %%
df['temp']=df['temp'].fillna(df['temp'].mean())
df
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd       NaN  67.0
# 6  bangalore      78.0  67.0

# %%
df.shape
# Out:
# (7, 3)

# %%
df['humidity']=df['humidity'].fillna(df['humidity'].sum())
df
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd     270.0  67.0
# 6  bangalore      78.0  67.0

# %%
df.columns
# Out:
# Index(['city', 'humidity', 'temp'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.dtypes
# Out:
# city         object
# humidity    float64
# temp        float64
# dtype: object

# %%
df.city
# Out:
# 0          Hyd
# 1          kkd
# 2          vzg
# 3          Hyd
# 4          vzg
# 5          kkd
# 6    bangalore
# Name: city, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd     270.0  67.0
# 6  bangalore      78.0  67.0>

# %%
df[2:6]
# Out:
#   city  humidity  temp
# 2  vzg      56.0  63.0
# 3  Hyd      23.0  32.0
# 4  vzg      34.0  89.0
# 5  kkd     270.0  67.0

# %%
data=({
    "Name":["Niha","Kavs","Vinay","Sri","Sai","Sagarika","Raju"],
    "Age": [12,23,45,67,23,23,12]
})
df
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd     270.0  67.0
# 6  bangalore      78.0  67.0

# %%
df.tail()
# Out:
#         city  humidity  temp
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd     270.0  67.0
# 6  bangalore      78.0  67.0

# %%
df.head()
# Out:
#   city  humidity  temp
# 0  Hyd      34.0  56.0
# 1  kkd      45.0  67.0
# 2  vzg      56.0  63.0
# 3  Hyd      23.0  32.0
# 4  vzg      34.0  89.0

# %%
df.shape
# Out:
# (7, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.isnull()
# Out:
#     city  humidity   temp
# 0  False     False  False
# 1  False     False  False
# 2  False     False  False
# 3  False     False  False
# 4  False     False  False
# 5  False     False  False
# 6  False     False  False

# %%
df.info
# Out:
# <bound method DataFrame.info of         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd     270.0  67.0
# 6  bangalore      78.0  67.0>

# %%
df[2:6]
# Out:
#   city  humidity  temp
# 2  vzg      56.0  63.0
# 3  Hyd      23.0  32.0
# 4  vzg      34.0  89.0
# 5  kkd     270.0  67.0

# %%
df['temp']=df['temp'].fillna(df['temp'].mean())
df
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0  63.0
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd     270.0  67.0
# 6  bangalore      78.0  67.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   city      7 non-null      object
#  1   humidity  7 non-null      float64
#  2   temp      7 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 300.0+ bytes
